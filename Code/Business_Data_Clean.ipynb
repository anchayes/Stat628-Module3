# %%
import json
import numpy as np
import pandas as pd

# %%
with open("/Users/annahayes/R_stuff/yelp_dataset_2022/business.json", "r") as f:
    df = pd.read_json(f, orient="records", lines=True)
df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
break_df = df[df['categories'].str.contains(
              'Breakfast|Brunch|Breakfast&Brunch|Breakfast & Brunch',
              case=False, na=False)]
len(break_df)
# Out:
# 6525

# %%
break_df.head()
# Out:
#                 business_id                  name                address  \
# 12   il_Ro8jwPlHresjw9EGmBg               Denny's           8901 US 31 S
# 47   lk9IwjZXqUMqqOhM774DtQ      Caviar & Bananas          2031 Broadway
# 85   IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery  131 Anacapa St, Ste C
# 155  hUQ9Z7kQeabvhPOAQOVV1A     Rathbone Mansions     1244 Esplanade Ave
# 206  IYlUaKC9nICjiWdk-ShPlg            Bub's Cafe          220 2nd St SW
#
#               city state postal_code   latitude   longitude  stars  \
# 12    Indianapolis    IN       46227  39.637133  -86.127217    2.5
# 47       Nashville    TN       37203  36.148371  -86.798895    3.5
# 85   Santa Barbara    CA       93101  34.414445 -119.690672    4.0
# 155    New Orleans    LA       70116  29.967055  -90.065828    3.5
# 206         Carmel    IN       46032  39.976614  -86.130124    4.0
#
#      review_count  is_open                                         attributes  \
# ...

# %%
df_cat = df.assign(categories = df.categories
                         .str.split(', ')).explode('categories')

# %%
df_cat[df_cat.categories.str.contains('Breakfast',
                      case=True,na=False)].categories.value_counts()
# Out:
# Breakfast & Brunch    6239
# Bed & Breakfast        324
# Name: categories, dtype: int64

# %%
csv_name = "yelp_business_breakfast.csv"
break_df.to_csv(csv_name, index=False)
